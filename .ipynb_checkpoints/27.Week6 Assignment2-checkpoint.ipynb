# %%
"""
Write a Python function that takes two numbers as input and 
returns the result of their division. 
Handle the ZeroDivisionError exception if the second number is zero. 
If there is ZeroDivisionError, the function should return -1.
"""

def divide(num1, num2):
    try:
        result=num1/num2
        return result
    except ZeroDivisionError:
        print("Division by zero cannot be done.")
        return -1

num1=float(input("Enetr first no:"))
num2=float(input("Enetr second no:"))
output=divide(num1, num2)
print(output)
# Out:
# Enetr first no: 50
# Enetr second no: 0
# Division by zero cannot be done.
# -1

# %%
"""
Write a Python program that asks the user to input their age. 
Handle the ValueError exception if the user enters a non-integer value.
"""

def getAge():
    try:
        age = int(input("Enter your age = "))
        return age
    except ValueError:
        print("Invalid input. Please enter a valid integer for age.")


age = getAge()
print(f"Age is {age}")

# %%
def getAge():
    try:
        age=int(input("Enter age:"))
        return age
    except ValueError:
        print("Invalid Input. Please enter a valid integer for age.")


age=getAge()
print(age)
# Out:
# Enter age: chg
# Invalid Input. Please enter a valid integer for age.
# None

# %%
"""
Write a Python dictionary that stores information about different fruits. 
Write a program that asks the user to input a fruit name and then prints its color. 
Handle the KeyError exception if the input fruit name is not found in the dictionary.
"""

fruits = {
    "apple": "red",
    "banana": "yellow",
    "orange": "orange",
    "grape": "purple",
    "watermelon": "green",
    "pineapple": "yellow",
}

def fruitDetails(fruits,name):
    try:
        detail=fruits[name]
        return detail
    except KeyError:
        print("Fruit not found in the dictionary.")
name=str(input("Enter fruit name:"))
detail=fruitDetails(fruits,name)
detail
# Out:
# Enter fruit name: acv
# Fruit not found in the dictionary.

# %%
"""
Write a function that takes a list as input and prints the element at index 5. 
Handle the IndexError exception if the list doesn't have enough elements.
"""

def printElement(input_list: list):
    try:
        element = input_list[5]
        print(f"Element at index 5 is = {element}")
    except IndexError:
        print("The list doesn't have enough elements.")


# Example usage:
my_list = [0, 1, 2, 3, 4]
printElement(my_list)
# Out:
# Index not found

# %%
"""
Write a function divide that takes two numbers as input and returns their division. 
Call this function with invalid input arguments (e.g., strings instead of numbers) 
and handle any exceptions that may occur.
"""
def divide(x, y):
    try:
        result = x / y
        return result
    except ZeroDivisionError:
        print("Division by zero is not allowed.")
        return None
    except TypeError:
        print("Invalid input type. Please provide numeric values.")
        return None

# %%
def divide(x,y):
    try:
        result=x/y
        return result
    except ZeroDivisionError:
        print("Division by zero is not allowed.")
        return None
    except TypeError:
        print("Invalid input type. Please provide numeric values.")
        return None

x=10
y="sa"
output=divide(x,y)
output
# Out:
# Invalid input type. Please provide numeric values.
