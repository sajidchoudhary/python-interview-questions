# %%
from typing import Dict, List

# %%
"""
Write a Python function that takes a dictionary as input where the values are lists. 
The function should return a new list containing all the elements from
all the lists in the dictionary.
It should have at least 3-4 keys and any amount of elements can be in a list.
"""

myDict={
    "sajid":[14,45,"a","b",74],
     "arshi":[47,85,"c","b",14],
    "mike":[74,"d","e","f"]
}

def returnList(myDict:Dict[str, list])->list:
    newList=[]
    for lists in myDict.values():
        for i in lists:
            newList.append(i)
    return newList


myNewList=returnList(myDict)
myNewList
# Out:
# [14, 45, 'a', 'b', 74, 47, 85, 'c', 'b', 14, 74, 'd', 'e', 'f']

# %%
'''
create a function named countChar which will accept a string as a parameter.
create a dictionary having frequency of each character.
'''

def countChar(myStr:str):
    myDict={}
    for i in myStr:
        if i in myDict:
            myDict[i] += 1
        else:
            myDict[i]=1
    return myDict


myStr="ssssaaaajiiiiiiddd"
newDict=countChar(myStr)
newDict
# Out:
# {'s': 4, 'a': 4, 'j': 1, 'i': 6, 'd': 3}

# %%
"""
Write a Python function that takes a dictionary as input where the 
values are lists of integers. 
The function should return a new dictionary where the values 
are lists containing only the even integers from the original lists
"""
myDict={"sajid":[1,2,3,4,5,6],
       "prince":[7,8,9,10,11,12]}

#Method1
def evenIntDict1(myDict:Dict[str, List[int]])->Dict:
    newDict={}
    for key, lists in myDict.items():
        even_List=[]
        for i in lists:
            if i%2==0:
                even_List.append(i)
        newDict[key]=even_List
    return newDict


#Method2
def evenIntDict2(myDict:Dict[str, List[int]])->Dict:
    newDict={}
    for key, lists in myDict.items():
        newDict[key]=[i for i in lists if i%2==0]
    return newDict


newans1=evenIntDict1(myDict)
print(newans1)

newans2=evenIntDict2(myDict)
print(newans2)
# Out:
# {'sajid': [2, 4, 6], 'prince': [8, 10, 12]}
# {'sajid': [2, 4, 6], 'prince': [8, 10, 12]}

# %%
"""
Write a Python function that takes two dictionaries as input, 
where the values are lists. The function should merge the lists 
corresponding to the same keys in both dictionaries into a 
single list and return a new dictionary with these merged lists.
"""


def mergeDictionary(dictionary1, dictionary2):
    merged_dictionary = {}

    # We do this for dictionary1
    for key in dictionary1:
        if key in dictionary2:
            merged_dictionary[key] = dictionary1[key] + dictionary2[key]
        else:
            merged_dictionary[key] = dictionary1[key]

    # Now we do for keys in dictionary2 not present in dictionary1
    for key in dictionary2:
        if key not in dictionary1:
            merged_dictionary[key] = dictionary2[key]

    return merged_dictionary


dict1 = {"x": [1, 2, 3], "y": [4, 5, 6]}
dict2 = {"x": [7, 8, 9], "y": [10, 11, 12], "z": [99, 100, 111]}
result = mergeDictionary(dict1, dict2)
print(result)
# Out:
# {'x': [1, 2, 3, 7, 8, 9], 'y': [4, 5, 6, 10, 11, 12], 'z': [99, 100, 111]}

# %%
"""
Write a Python program to combine two dictionary by adding values
for common keys.
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
Sample output: {'a': 400, 'b': 400, 'd': 400, 'c': 300}
"""

#Method1
def combineDictionary1(d1, d2):
    outputDict={}
    for key, value in d1.items():
        if key in d2:
            outputDict[key]=d1[key]+d2[key]
        else:
            outputDict[key]=d1[key]
    for key, value in d2.items():
        if key not in d1:
            outputDict[key]=d2[key]
    return outputDict

#Method2
def combineDictionary2(d1, d2):
    combined_dict = {}

    for key in d1:
        combined_dict[key] = d1[key] + d2.get(key, 0)

    # Do for keys from d2 not present in d1
    for key in d2:
        if key not in d1:
            combined_dict[key] = d2[key]

    return combined_dict


# Method 3 OPTIMAL WAY
def combineDictionary3(d1, d2):
    combined_dict = {}

    # This combines keys of both d1 and d2
    for key in d1.keys() | d2.keys():
        combined_dict[key] = d1.get(key, 0) + d2.get(key, 0)

    return combined_dict

d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400, 'e':500} 

outputDict1=combineDictionary(d1, d2)
outputDict1
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400, 'e': 500}

# %%
"""
Write a Python program to create a dictionary of keys x, y, and z 
where each key has as value a list from 11-20, 21-30, and 31-40 respectively. 
Access the fifth value of each key from the dictionary.
{'x': [11, 12, 13, 14, 15, 16, 17, 18, 19],'y': [21, 22, 23, 24, 25, 26, 27, 28, 29],'z': [31, 32, 33, 34, 35, 36, 37, 38, 39]}

Output 
15
25
35
"""

# You can create dictionary like this too
data = {
    "x": list(range(11, 20)),
    "y": list(range(21, 30)),
    "z": list(range(31, 40)),
}

for key, value in data.items():
    print(value[4])
# Out:
# 15
# 25
# 35

# %%
"""
Store name as a Key, and 5 marks in a List as a value in dictionary. 
Store details of at least 5 students. 
Print the total marks with percentage of each and every student
"""
myDict={}
noOfStudents=int(input("Enter no of Student:"))
for _ in range(noOfStudents):
    name=str(input("Name of student:"))
    noOfSubs=int(input("Enter No of Subjects:"))
    marks=[]
    for i in range(noOfSubs):
        mark=int(input(f"Enter student {name} subject mark:"))
        marks.append(mark)
    myDict[name]=marks

for stu, marks in myDict.items():
    total=sum(marks)
    n=len(marks)
    percentage=(total/500)*100
    print(f"{stu} total marks {total} and percentage {percentage}")
# Out:
# Enter no of Student: 5
# Name of student: Sajid
# Enter No of Subjects: 5
# Enter student Sajid subject mark: 78
# Enter student Sajid subject mark: 85
# Enter student Sajid subject mark: 95
# Enter student Sajid subject mark: 45
# Enter student Sajid subject mark: 25
# Name of student: Arshi
# Enter No of Subjects: 5
# Enter student Arshi subject mark: 78
# Enter student Arshi subject mark: 88
# Enter student Arshi subject mark: 99
# Enter student Arshi subject mark: 95
# Enter student Arshi subject mark: 65
# Name of student: Ehan
# Enter No of Subjects: 5
# Enter student Ehan subject mark: 74
# Enter student Ehan subject mark: 78
# Enter student Ehan subject mark: 95
# Enter student Ehan subject mark: 65
# Enter student Ehan subject mark: 32
# Name of student: Hamza
# Enter No of Subjects: 5
# Enter student Hamza subject mark: 77
# Enter student Hamza subject mark: 41
# Enter student Hamza subject mark: 51
# Enter student Hamza subject mark: 69
# ...

# %%
"""
Given a dictionary with key-value pairs, remove all the keys with values 
greater than K, including mixed values.
Input : test_dict = {'Gfg' : 3, 'is' : 7, 'best' : 10, 'for' : 6, 'xyzx' : 'CS'}, K = 7 
Output : {'Gfg' : 3, 'for' : 6, 'xyzx' : 'CS'} 
Explanation : All values greater than K are removed. Mixed value is retained. 
Input : test_dict = {'Gfg' : 3, 'is' : 7, 'best' : 10, 'for' : 6, 'qqqq' : 'CS'}, K = 1 
Output : {'qqqq' : 'CS'} 
Explanation : Only Mixed value is retained.
"""
def removeKeys(dictionary: Dict, K: int):
    # Uncomment this, if you want to change in original dictionary
    dictt = dictionary.copy()

    keys_to_remove = []
    for key, value in dictt.items():
        if type(value) == int and value > K:
            keys_to_remove.append(key)

    for key in keys_to_remove:
        dictt.pop(key)

    return dictt


test_dict1 = {"Gfg": 3, "is": 7, "best": 10, "for": 6, "xyzx": "CS"}
test_dict2 = {"Gfg": 3, "is": 7, "best": 10, "for": 6, "qqqq": "CS"}
K1 = 7
K2 = 1

output1 = removeKeys(test_dict1, K1)
output2 = removeKeys(test_dict2, K2)

print(output1)
print(output2)
# Out:
# {'Gfg': 3, 'is': 7, 'for': 6, 'xyzx': 'CS'}
# {'qqqq': 'CS'}

# %%
"""
A Python dictionary contains List as a value. 
Write a Python program to clear the list values in the said dictionary.
Original Dictionary:{'C1': [10, 20, 30], 'C2': [20, 30, 40], 'C3': [12, 34]}
Clear the list values in the said dictionary:{'C1': [], 'C2': [], 'C3': []}
"""


def clearList(dictionary):
    for key in dictionary:
        dictionary[key] = []


original_dict = {"C1": [10, 20, 30], "C2": [20, 30, 40], "C3": [12, 34]}

clearList(original_dict)

print(original_dict)
# Out:
# {'C1': None, 'C2': None, 'C3': None}
