# %% [markdown]
# ### Introduction

# %%
my_String = "python is coding language"

print(my_String)
print(my_String[0])
print(my_String[1])
print(my_String[-1])
print(my_String[6])
# Out:
# python is coding language
# p
# y
# e

# %%
# Iterable

a = "hndjawkhd bjkawdbn jkawdnbhj kwahndjkwan"
print(a)
print(type(a))
# Out:
# hndjawkhd bjkawdbn jkawdnbhj kwahndjkwan
# <class 'str'>

# %%
a = "abc" + "xyz"
print(a, id(a))  # abcxyz

b = a + "pqr"
print(b, id(b))

x = "12%$3456"

a = "abc" * 3
print(a)
# Out:
# abcxyz 2088931831216
# abcxyzpqr 2088931835184
# abcabcabc

# %%
# Strings are immutable

my_String = "python is coding language"
my_String[0] = "z"

print(my_String)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Strings are immutable
#       3 my_String = "python is coding language"
# ----> 4 my_String[0] = "z"
#       6 print(my_String)
#
# TypeError: 'str' object does not support item assignment

# %%
# String slicing
# a[start : stop : step]

'''
start → where to begin (default = 0)
stop → where to end (default = end of string)
step → jump size
'''

a = "python is good"

# print(a[0:3])
# print(a[::-1])
print(a[::2])
print(a[-5:])
# Out:
# pto sgo
#  good

# %%
my_String = "python is coding language"

# By Index
# for i in range(0, len(my_String)):
#     print(my_String[i])

# BY Value
# for i in my_String:
#     print(i)

for i, ch in enumerate(my_String):
    print(i, ch)
# Out:
# 0 p
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n
# 6
# 7 i
# 8 s
# 9
# 10 c
# 11 o
# 12 d
# 13 i
# 14 n
# 15 g
# 16
# 17 l
# 18 a
# 19 n
# 20 g
# 21 u
# 22 a
# 23 g
# 24 e

# %%
# Membership Operator
# in / not in (iterable)

char = "@"

if char.isalpha():
    if char not in "aeiou":
        print("Con")
    else:
        print("No")
else:
    print("Nono")
# Out:
# Nono

# %%
a = "python is Ooa cool coding language"
# ord('o')  # 111
# ord('O')  # 79
count = 0
for ch in a:
    if ord(ch) == 111 or ord(ch) == 79:
        count += 1

print(count)
# Out:
# 6

# %%
#Count the number of digits present between ord(48) and ord(57) in a given string. 
a = "my age is 27 and phohdjk463278bvdkl,&*(^&%11)"


count = 0
for ch in a:
    if ord(ch)>=48 and ord(ch)<=57:
        count+=1

print(count)
# Out:
# 10

# %% [markdown]
# ### string methods, joining and spliting

# %%
my_string = "python is good language"

# language good is python
# egaugnal doog # Slicing

r = my_string.split()
print(r)
# Out:
# ['python', 'is', 'good', 'language']

# %%
# Joining
# List to String

a = ["python", "is", "good", "language", True, 99.99]
# a = [1, 5, 7, 11, 225]

x = " ".join(str(i) for i in a)
print(x)
# Out:
# python is good language True 99.99

# %%
my_string = "56473A8596%^&*$%    &^*"


# my_string = my_string.lower()
# my_string = my_string.upper()
# my_string = my_string.title()
# my_string = my_string.capitalize()
# my_string = my_string.swapcase()
# x = my_string.islower()
x = my_string.isupper()

print(x)

# %%
x = input("Enter a number = ")  # one

# If digit, then convert to int, else print INVALID
if x.isdigit():
    x = int(x)
    print(x, type(x))
else:
    print("INVALID")
# Out:
# Enter a number =  one
# INVALID

# %%
my_string = input("Enter a string = ")  # ANIrudh

count = 0
for ch in my_string:
    if ch.islower():
        count += 1
    # ascii = ord(ch)
    # if ascii >= 97 and ascii <= 122:
    #     count += 1

print(count)
# Out:
# Enter a string =  sajid
# 5

# %%
my_string = "00001230000000"


# x = my_string.isalpha()
# x = my_string.isalnum()
x = my_string.isdigit()

print(x)
# Out:
# True

# %% [markdown]
# ### String method

# %%
a = "Anirudh"
b = "AnirudH"
print(a > b)
#ord('h')  # 104
#ord('H')  # 72
# Out:
# True

# %%
char = "F"

if ("a" <= char <= "z") or ("A" <= char <= "Z"):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
string = "python is a coding language"
x = list(string)
print(x)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', ' ', 'i', 's', ' ', 'a', ' ', 'c', 'o', 'd', 'i', 'n', 'g', ' ', 'l', 'a', 'n', 'g', 'u', 'a', 'g', 'e']

# %%
x[0] = "Z"
print(x)
print(type(x))
# Out:
# ['Z', 'y', 't', 'h', 'o', 'n', ' ', 'i', 's', ' ', 'a', ' ', 'c', 'o', 'd', 'i', 'n', 'g', ' ', 'l', 'a', 'n', 'g', 'u', 'a', 'g', 'e']
# <class 'list'>

# %%
string = "python is a coding language"
x = list(string)
r = "".join(i for i in x[::-1])
# r = "".join(i for i in x)
print(r)
print(type(r))
# Out:
# egaugnal gnidoc a si nohtyp
# <class 'str'>

# %%
string = "python is a coding language"
string.replace("o","O")
# Out:
# 'pythOn is a cOding language'

# %%
"""
Keep asking characters from user.
Until user tpyes quit

Enter character = a
Enter character = b
Enter character = c
Enter character = d
Enter character = d
Enter character = d
Enter character = e

abcddde
"""

my_string = ""
while True:
    char = input("Enter a char = ")
    if char == "quit":
        break
    my_string += char

print(my_string)
# Out:
# Enter a char =  a
# Enter a char =  c
# Enter a char =  s
# Enter a char =  quit
# acs

# %%
my_string = "pyTH@#on is GOO!@d"

result = ""

for i in my_string:
    if i.isalpha():
        if i.isupper():
            result += i.lower()
        elif i.islower():
            result += i.upper()
    else:
        result += i
print(result)
# Out:
# PYth@#ON IS goo!@D

# %%
my_string = "apyTH@#on is GOO!@d"

result = ""


for i in my_string:
    ascii_code = ord(i)
    if ascii_code >= 97 and ascii_code <= 122:
        capital_letter = chr(ascii_code - 32)
        result += capital_letter
    elif ascii_code >= 65 and ascii_code <= 90:
        small_letter = chr(ascii_code + 32)
        result += small_letter
    else:
        result += i

print(result)
# Out:
# APYth@#ON IS goo!@D
