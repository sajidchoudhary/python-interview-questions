# %%
dictionary = {
    "name": "Sajid",
    "age": 44,
    "gender": "Male",
    # 1: "abc",
    2: 3,
    3: 3,
    False: False,
    True: True,
    # [1, 2, 3]: "Sajid",
    (1, 2, 3): "Sajid",
    None: 55,
}

print(dictionary)
# Out:
# {'name': 'Sajid', 'age': 44, 'gender': 'Male', 2: 3, 3: 3, False: False, True: True, (1, 2, 3): 'Sajid', None: 55}

# %%
s1_detail = {"name": "sajid", "age": 55, "gender": "Male"}
s2_detail = {"name": "Sanjay", "age": 15, "gender": "Male"}

print(s1_detail)
print(type(s1_detail))
print(s2_detail)
print(type(s2_detail))
# Out:
# {'name': 'sajid', 'age': 55, 'gender': 'Male'}
# <class 'dict'>
# {'name': 'Sanjay', 'age': 15, 'gender': 'Male'}
# <class 'dict'>

# %%
detail = {
    "name": "sajid",
    "age": 55,
    "gender": "Male",
}
print(detail)

# Add (if key does not exists)/ update (if key exists)
# detail["name"] = "arshi"
# detail["age"] = 100
detail["address"] = "mzn"
detail["marks"] = [1, 2, 3, 4]
print(detail)
# Out:
# {'name': 'sajid', 'age': 55, 'gender': 'Male'}
# {'name': 'sajid', 'age': 55, 'gender': 'Male', 'address': 'mzn', 'marks': [1, 2, 3, 4]}

# %%
del detail["name"]
print(detail)
# Out:
# {'age': 55, 'gender': 'Male', 'address': 'mzn', 'marks': [1, 2, 3, 4]}

# %%
detail = {
    "name": "Sajid",
    "age": 55,
    "gender": "Male",
}

print(list(detail))
# Out:
# ['name', 'age', 'gender']

# %%
x = str(detail)
print(x)
print(x[0])
print(x[1])
print(x[2])
print(x[3])
# Out:
# {'name': 'Sajid', 'age': 55, 'gender': 'Male'}
# {
# '
# n
# a

# %%
detail = {"name": "sajid", "age": 55}

b = {"gender": "Male"}

#print(detail + b)

print(detail * 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       3 b = {"gender": "Male"}
#       5 #print(detail + b)
# ----> 7 print(detail * 3)
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
detail = {
    "name": "sajid",
    "age": 55,
    "gender": "Male",
}

# Iterating
# for i in detail.keys():
#     print(i, detail[i])

# for i in detail.values():
#     print(i)

for k, v in detail.items():
    # print(f"Key = {k} and Value = {v}")
    print(f"{k}={v}")
# Out:
# name=sajid
# age=55
# gender=Male

# %%
detail = {
    "name": "sajid",
    "age": 55,
    "gender": "Male",
    0: "",
    "physics": 66,
    "maths": 91,
    "science": 100,
}
total_marks = detail["physics"] + detail["maths"] + detail["science"]
print(total_marks)


print(f"Your total is {detail['physics'] + detail['maths'] + detail['science']}")


# print(total_marks)
# print(detail["name"])
# print(detail["age"])
# print(detail["gender"])
# print(detail[0])
# print(detail["genderr"])
# Out:
# 257
# Your total is 257

# %%
marks = {
    "physics": 67,
    "comp": 10,
    "science": 99,
    "english": 82,
    "hindi": 17,
}

print(sum(marks.values()))
total = 0
for mark in marks.values():
    total = total + mark

print(total)
# Out:
# 275
# 275
