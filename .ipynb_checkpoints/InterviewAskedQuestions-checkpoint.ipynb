# %%
'''
Given an integer array nums and an integer k, 
return the k most frequent elements within the array. 
You may return the output in any order. 
Example 1:Input: nums = [1,2,2,3,3,3], k = 2 Output: [2,3] 
Input: nums = [7,7], k = 1 Output: [7]
'''

nums = [5,5,5,5,1,2,2,3,3,3,3]
k = 2
def topKFrequent(nums,k):
    freq={}
    for i in range(len(nums)):
        if nums[i] not in freq:
            freq[nums[i]]=1
        else:
            freq[nums[i]]+=1
    
    topk=[key for key, value in sorted(freq.items(), key=lambda x:x[1], reverse=True)[:k]]
    return topk
output=topKFrequent(nums,k)
output
# Out:
# [5, 3]

# %%
doc = {
"title": "Company Leave Policy",
"text": """
Employees receive 20 days of annual leave. Sick leave policies allow up to 10 days per year.
Leave requests must be submitted through the HR portal and approved by the reporting manager.
Extended leave beyond 30 days requires HR approval.
"""
}

"8 words ke chunks chahiye aur 2 words overlap bhi chahiye, saath hi metadata (id, title) add karna hai."

chunk_size = 8
overlap = 2
step = chunk_size - overlap

words = doc["text"].split()

chunks = []

for i in range(0, len(words), step):
    chunk_words = words[i:i + chunk_size]
    
    if len(chunk_words) < chunk_size:
        break
        
    chunk = {
        "id": len(chunks) + 1,
        "title": doc["title"],
        "text": " ".join(chunk_words)
    }
    
    chunks.append(chunk)

for c in chunks:
    print(c)
# Out:
# ['Employees', 'receive', '20', 'days', 'of', 'annual', 'leave.', 'Sick']
# ['leave.', 'Sick', 'leave', 'policies', 'allow', 'up', 'to', '10']
# ['to', '10', 'days', 'per', 'year.', 'Leave', 'requests', 'must']
# ['requests', 'must', 'be', 'submitted', 'through', 'the', 'HR', 'portal']
# ['HR', 'portal', 'and', 'approved', 'by', 'the', 'reporting', 'manager.']
# ['reporting', 'manager.', 'Extended', 'leave', 'beyond', '30', 'days', 'requires']
# ['days', 'requires', 'HR', 'approval.']
# {'id': 1, 'title': 'Company Leave Policy', 'text': 'Employees receive 20 days of annual leave. Sick'}
# {'id': 2, 'title': 'Company Leave Policy', 'text': 'leave. Sick leave policies allow up to 10'}
# {'id': 3, 'title': 'Company Leave Policy', 'text': 'to 10 days per year. Leave requests must'}
# {'id': 4, 'title': 'Company Leave Policy', 'text': 'requests must be submitted through the HR portal'}
# {'id': 5, 'title': 'Company Leave Policy', 'text': 'HR portal and approved by the reporting manager.'}
# {'id': 6, 'title': 'Company Leave Policy', 'text': 'reporting manager. Extended leave beyond 30 days requires'}

# %%
doc = {
"title": "Company Leave Policy",
"text": """
Employees receive 20 days of annual leave. Sick leave policies allow up to 10 days per year.
Leave requests must be submitted through the HR portal and approved by the reporting manager.
Extended leave beyond 30 days requires HR approval.
"""
}

chunk_size=8
overlap=2
step=chunk_size-overlap
chunks=[]
words=doc["text"].split()

for i in range(0, len(words), step):
    chunk_words=words[i:i+chunk_size]
    
    if len(chunk_words)<chunk_size:
        break
    return {
        "id":len(chunks)+1,
        "title":doc["title"],
        "text": 
    }
# Out:
#   Cell In[3], line 19
#
#     ^
# SyntaxError: incomplete input
